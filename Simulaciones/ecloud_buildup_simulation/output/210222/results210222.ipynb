# %%
import matplotlib.pyplot as plt
import scipy.io

data = scipy.io.loadmat("Pyecltest_angle3D.mat")

vars  = list(data.keys())
vars.remove('__header__')
vars.remove('__version__')
vars.remove('__globals__')
for key in vars:
    print('Parametro:' , key, 'Tamaño:', data[key].shape, "Tipo:", data[key].dtype)
# Out:
# Parametro: t_hist Tamaño: (1, 36) Tipo: float64
# Parametro: nel_hist Tamaño: (36, 47) Tipo: float64
# Parametro: xg_hist Tamaño: (1, 47) Tipo: float64
# Parametro: nel_impact_hist_tot Tamaño: (36, 47) Tipo: float64
# Parametro: nel_impact_hist_scrub Tamaño: (36, 47) Tipo: float64
# Parametro: energ_eV_impact_hist Tamaño: (36, 47) Tipo: float64
# Parametro: En_g_hist Tamaño: (1, 250) Tipo: float64
# Parametro: En_hist Tamaño: (36, 250) Tipo: float64
# Parametro: En_hist_seg Tamaño: (1, 1) Tipo: int64
# Parametro: all_Ekin_hist Tamaño: (36, 250) Tipo: float64
# Parametro: t_En_hist Tamaño: (1, 36) Tipo: float64
# Parametro: b_spac Tamaño: (1, 1) Tipo: float64
# Parametro: t_sc_video Tamaño: (1, 1689) Tipo: float64
# Parametro: U_sc_eV Tamaño: (1, 1689) Tipo: float64
# Parametro: N_mp_impact_pass Tamaño: (1, 36) Tipo: int64
# Parametro: N_mp_corrected_pass Tamaño: (1, 36) Tipo: int64
# Parametro: N_mp_pass Tamaño: (1, 36) Tipo: int64
# ...

# %%
plt.plot(data['t'].flatten(),data['cen_density'].flatten())
plt.show()

# %%
plt.plot(data['t'].flatten(),data['Nel_timep'].flatten())
plt.show()

# %%
plt.plot(data['t'].flatten(),data['En_kin_eV_time'].flatten())
plt.show()

# %%
print("hola")
